# %% [markdown]
# ## Carrega a planilha de dados
#
# Lê o arquivo CSV "dados_questionario.csv" em um data frame

# %%
todos_dados.df <- read.csv2("dados_questionario.csv")

# %% [markdown]
# ### Definição das colunas dos dados

# %%
colunas.var <- c("P1","P2","P3","P4","P5","P6","P7","P8","P9","P10", "P11") # Define as colunas a serem usadas nos cálculos

# %% [markdown]
# ### INICIO DOS CÁLCULOS
#
# Alpha de Cronbach é bom acima de 0.7

# %%
library(psychometric) # Carrega a biblioteca para análise psicométrica
alpha(todos_dados.df[colunas.var]) # Calcula o Alpha de Cronbach para as colunas especificadas
# Out:
# [1] 0.8807644

# %% [markdown]
# ## Cáculo da Correlação de Pearson OU Spearman
# (elimina os NAs -> pairwise.complete.obs)

# %%
(v_cor <- cor(todos_dados.df[colunas.var], use=c("pairwise.complete.obs"), method=c("pearson"))) # Calcula a matriz de correlação
# Out:
#     P1        P2        P3        P4        P5        P6        P7
# P1  1.0000000 0.6853263 0.5379936 0.5985607 0.5970951 0.4060306  0.24823052
# P2  0.6853263 1.0000000 0.5540033 0.5319386 0.7001196 0.3854062  0.31889602
# P3  0.5379936 0.5540033 1.0000000 0.5104704 0.6150542 0.6917351  0.19763368
# P4  0.5985607 0.5319386 0.5104704 1.0000000 0.5234231 0.4418807  0.25495525
# P5  0.5970951 0.7001196 0.6150542 0.5234231 1.0000000 0.4873746  0.25244267
# P6  0.4060306 0.3854062 0.6917351 0.4418807 0.4873746 1.0000000  0.31874497
# P7  0.2482305 0.3188960 0.1976337 0.2549553 0.2524427 0.3187450  1.00000000
# P8  0.2815421 0.3466393 0.2770934 0.3464108 0.4340730 0.1297486  0.19116394
# P9  0.4288427 0.4049063 0.5826731 0.4443576 0.3890637 0.4506803  0.10584871
# P10 0.5091083 0.4625435 0.6742234 0.5088124 0.5124752 0.5721811 -0.07276023
# P11 0.4718317 0.5122353 0.4449098 0.4593312 0.3524991 0.3438635  0.27877020
#     P8        P9        P10         P11
# P1  0.2815421 0.4288427  0.50910830 0.4718317
# P2  0.3466393 0.4049063  0.46254354 0.5122353
# P3  0.2770934 0.5826731  0.67422337 0.4449098
# P4  0.3464108 0.4443576  0.50881240 0.4593312
# P5  0.4340730 0.3890637  0.51247523 0.3524991
# P6  0.1297486 0.4506803  0.57218108 0.3438635
# P7  0.1911639 0.1058487 -0.07276023 0.2787702
# P8  1.0000000 0.3471388  0.24042696 0.1721757
# P9  0.3471388 1.0000000  0.67512010 0.5432117
# P10 0.2404270 0.6751201  1.00000000 0.4373141
# P11 0.1721757 0.5432117  0.43731414 1.0000000

# %% [markdown]
# ##### Verifica quais são as correlações significativas

# %%
symnum(v_cor) # Mostra as correlações significativas
# Out:
#     P1 P2 P3 P4 P5 P6 P7 P8 P9 P10 P11
# P1  1
# P2  ,  1
# P3  .  .  1
# P4  .  .  .  1
# P5  .  ,  ,  .  1
# P6  .  .  ,  .  .  1
# P7     .           .  1
# P8     .     .  .        1
# P9  .  .  .  .  .  .     .  1
# P10 .  .  ,  .  .  .        ,  1
# P11 .  .  .  .  .  .        .  .   1
# attr(,"legend")
# [1] 0 ‘ ’ 0.3 ‘.’ 0.6 ‘,’ 0.8 ‘+’ 0.9 ‘*’ 0.95 ‘B’ 1
