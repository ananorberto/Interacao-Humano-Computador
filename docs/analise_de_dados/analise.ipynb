# %% [markdown]
# ## Carrega a planilha de dados
#
# Lê o arquivo CSV "dados_questionario.csv" em um data frame

# %%
todos_dados.df <- read.csv2("dados_questionario.csv")

# %% [markdown]
# ### Definição das colunas dos dados

# %%
colunas.var <- c("P1","P2","P3","P4","P5","P6","P7","P8","P9","P10","P11","P12","P13") # Define as colunas a serem usadas nos cálculos

# %% [markdown]
# ### INICIO DOS CÁLCULOS
#
# Alpha de Cronbach é bom acima de 0.7

# %%
library(psychometric) # Carrega a biblioteca para análise psicométrica
alpha(todos_dados.df[colunas.var]) # Calcula o Alpha de Cronbach para as colunas especificadas
# Out:
# Carregando pacotes exigidos: dplyr
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Carregando pacotes exigidos: multilevel
#
# Carregando pacotes exigidos: nlme
#
#
# Attaching package: 'nlme'
#
#
# The following object is masked from 'package:dplyr':
#
#     collapse
#
#
# Carregando pacotes exigidos: MASS
#
#
# Attaching package: 'MASS'
#
#
# The following object is masked from 'package:dplyr':
#
#     select
#
#
# Carregando pacotes exigidos: purrr
# [1] 0.7965641

# %% [markdown]
# ## Cáculo da Correlação de Pearson OU Spearman
# (elimina os NAs -> pairwise.complete.obs)

# %%
(v_cor <- cor(todos_dados.df[colunas.var], use=c("pairwise.complete.obs"), method=c("pearson"))) # Calcula a matriz de correlação
# Out:
#     P1          P2          P3        P4          P5          P6
# P1   1.00000000 -0.01666583 0.1553411 -0.15069781 -0.02552223 -0.00329361
# P2  -0.01666583  1.00000000 0.6711894  0.50611355  0.59540809  0.52549922
# P3   0.15534115  0.67118938 1.0000000  0.55750318  0.52282046  0.65862504
# P4  -0.15069781  0.50611355 0.5575032  1.00000000  0.50657437  0.57567827
# P5  -0.02552223  0.59540809 0.5228205  0.50657437  1.00000000  0.43452409
# P6  -0.00329361  0.52549922 0.6586250  0.57567827  0.43452409  1.00000000
# P7  -0.12646041  0.38542906 0.3701016  0.69088114  0.43251041  0.46559313
# P8   0.05491058  0.26740146 0.3263587  0.16620332  0.25550323  0.18195323
# P9  -0.10444835  0.26760384 0.3740205  0.26660964  0.30014760  0.45569555
# P10 -0.01497163  0.40722271 0.4256056  0.60779299  0.43450431  0.39069569
# P11 -0.02509420  0.49709687 0.4804403  0.68327966  0.50472640  0.49218702
# P12  0.03687278  0.47311988 0.4854732  0.38128192  0.44360714  0.29735052
# P13  0.29669369  0.17036868 0.2232186  0.05629032  0.11441584  0.19034675
#     P7         P8          P9         P10         P11         P12
# P1  -0.1264604  0.05491058 -0.1044484 -0.01497163 -0.02509420 0.03687278
# P2   0.3854291  0.26740146  0.2676038  0.40722271  0.49709687 0.47311988
# P3   0.3701016  0.32635869  0.3740205  0.42560559  0.48044030 0.48547320
# P4   0.6908811  0.16620332  0.2666096  0.60779299  0.68327966 0.38128192
# P5   0.4325104  0.25550323  0.3001476  0.43450431  0.50472640 0.44360714
# P6   0.4655931  0.18195323  0.4556956  0.39069569  0.49218702 0.29735052
# P7   1.0000000  0.27102266  0.1066142  0.45712385  0.56817622 0.30369279
# P8   0.2710227  1.00000000  0.2085243  0.09517561 -0.06229386 0.28954749
# P9   0.1066142  0.20852428  1.0000000  0.35691281  0.25578590 0.16096962
# P10  0.4571239  0.09517561  0.3569128  1.00000000  0.68744750 0.48383764
# P11  0.5681762 -0.06229386  0.2557859  0.68744750  1.00000000 0.40437075
# P12  0.3036928  0.28954749  0.1609696  0.48383764  0.40437075 1.00000000
# P13  0.2558772  0.24373088  0.0651501  0.24192121  0.19898948 0.28929523
#     P13
# P1  0.29669369
# P2  0.17036868
# P3  0.22321863
# P4  0.05629032
# P5  0.11441584
# P6  0.19034675
# P7  0.25587721
# P8  0.24373088
# P9  0.06515010
# P10 0.24192121
# P11 0.19898948
# P12 0.28929523
# P13 1.00000000

# %% [markdown]
# ##### Verifica quais são as correlações significativas

# %%
symnum(v_cor) # Mostra as correlações significativas
# Out:
#     P1 P2 P3 P4 P5 P6 P7 P8 P9 P10 P11 P12 P13
# P1  1
# P2     1
# P3     ,  1
# P4     .  .  1
# P5     .  .  .  1
# P6     .  ,  .  .  1
# P7     .  .  ,  .  .  1
# P8        .              1
# P9        .     .  .        1
# P10    .  .  ,  .  .  .     .  1
# P11    .  .  ,  .  .  .        ,   1
# P12    .  .  .  .     .        .   .   1
# P13                                        1
# attr(,"legend")
# [1] 0 ' ' 0.3 '.' 0.6 ',' 0.8 '+' 0.9 '*' 0.95 'B' 1

# %% [markdown]
# ## Calculo do desvio padrão

# %%
(dp <- c(sd(todos_dados.df$P1),
        sd(todos_dados.df$P2),
        sd(todos_dados.df$P3),
        sd(todos_dados.df$P4),
        sd(todos_dados.df$P5),
        sd(todos_dados.df$P6),
        sd(todos_dados.df$P7),
        sd(todos_dados.df$P8),
        sd(todos_dados.df$P9),
        sd(todos_dados.df$P10),
        sd(todos_dados.df$P11),
        sd(todos_dados.df$P12),
        sd(todos_dados.df$P13)))

dataDp <- data.table(questao = colunas.var, data = dp)
# Out:
#  [1] 2.8047944 1.0899156 1.0800049 1.1714298 1.1480298 1.1639754 1.3194360
#  [8] 1.4977368 1.3886380 1.3595728 1.4076814 1.2426950 0.9706391
